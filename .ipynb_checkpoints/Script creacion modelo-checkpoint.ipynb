# %% [markdown]
# ## Script Modelo Popularidad
#
# El siguiente script tiene el código que se utilizó para entrenar y exportar el modelo con el que se harán las predicciones. El modelo se guardará en un archivo llamado popularity.pkl y se encontrará dentro de la carpeta de model_deployment.

# %%
# Importación librerías
import pandas as pd
import numpy as np

# %%
# Carga de datos de archivo .csv
dataTraining = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2025/main/datasets/dataTrain_Spotify.csv')
dataTesting = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2025/main/datasets/dataTest_Spotify.csv', index_col=0)

# %%
from sklearn.ensemble import RandomForestRegressor

x_train = dataTraining.drop(columns=['Unnamed: 0','track_id', 'artists', 'album_name', 'track_name', 'track_genre', 'popularity'])
y_train = dataTraining['popularity']

x_test = dataTesting.drop(columns=['track_id', 'artists', 'album_name', 'track_name', 'track_genre'])

# %%
x_train.head()
# Out:
#    duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0       211533     False         0.305  0.8490    9   -10.795     1
# 1       196000     False         0.287  0.1900    7   -12.030     0
# 2       216506     False         0.583  0.5090    1    -9.661     1
# 3       218346     False         0.163  0.0368    8   -23.149     1
# 4       173160     False         0.647  0.9210    2    -7.294     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0549      0.000058          0.056700    0.4640   0.3200  141.793
# 1       0.0370      0.930000          0.000356    0.0834   0.1330   83.685
# 2       0.0362      0.777000          0.202000    0.1150   0.5440   90.459
# 3       0.0472      0.991000          0.899000    0.1070   0.0387   69.442
# 4       0.1850      0.000939          0.371000    0.1310   0.1710  137.981
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               3
# ...

# %%
rf = RandomForestRegressor(n_estimators=200, max_depth=6, random_state=1)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=6, n_estimators=200, random_state=1)

# %%
import joblib
joblib.dump(rf, 'model_deployment/rf.pkl', compress=3)
# Out:
# ['model_deployment/rf.pkl']

# %%
# Importar modelo y predicción
from model_deployment.predict_script import predict_popularity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Importar modelo y predicción
# ----> 2 from model_deployment.predict_script import predict_popularity
#
# ModuleNotFoundError: No module named 'model_deployment.predict_script'
